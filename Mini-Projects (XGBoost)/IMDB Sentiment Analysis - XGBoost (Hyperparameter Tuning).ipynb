# %% [markdown]
# # Sentiment Analysis
#
# ## Using XGBoost in SageMaker
#
# _Deep Learning Nanodegree Program | Deployment_
#
# ---
#
# In this example of using Amazon's SageMaker service we will construct a random tree model to predict the sentiment of a movie review. You may have seen a version of this example in a pervious lesson although it would have been done using the sklearn package. Instead, we will be using the XGBoost package as it is provided to us by Amazon.
#
# ## Instructions
#
# Some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this notebook. You will not need to modify the included code beyond what is requested. Sections that begin with '**TODO**' in the header indicate that you need to complete or implement some portion within them. Instructions will be provided for each section and the specifics of the implementation are marked in the code block with a `# TODO: ...` comment. Please be sure to read the instructions carefully!
#
# In addition to implementing code, there will be questions for you to answer which relate to the task and your implementation. Each section where you will answer a question is preceded by a '**Question:**' header. Carefully read each question and provide your answer below the '**Answer:**' header by editing the Markdown cell.
#
# > **Note**: Code and Markdown cells can be executed using the **Shift+Enter** keyboard shortcut. In addition, a cell can be edited by typically clicking it (double-click for Markdown cells) or by pressing **Enter** while it is highlighted.

# %% [markdown]
# ## Step 1: Downloading the data
#
# The dataset we are going to use is very popular among researchers in Natural Language Processing, usually referred to as the [IMDb dataset](http://ai.stanford.edu/~amaas/data/sentiment/). It consists of movie reviews from the website [imdb.com](http://www.imdb.com/), each labeled as either '**pos**itive', if the reviewer enjoyed the film, or '**neg**ative' otherwise.
#
# > Maas, Andrew L., et al. [Learning Word Vectors for Sentiment Analysis](http://ai.stanford.edu/~amaas/data/sentiment/). In _Proceedings of the 49th Annual Meeting of the Association for Computational Linguistics: Human Language Technologies_. Association for Computational Linguistics, 2011.
#
# We begin by using some Jupyter Notebook magic to download and extract the dataset.

# %%
# %mkdir ../data
# !wget -O ../data/aclImdb_v1.tar.gz http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# !tar -zxf ../data/aclImdb_v1.tar.gz -C ../data
# Out:
# mkdir: cannot create directory ‘../data’: File exists
# --2019-06-28 17:20:00--  http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# Resolving ai.stanford.edu (ai.stanford.edu)... 171.64.68.10
# Connecting to ai.stanford.edu (ai.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84125825 (80M) [application/x-gzip]
# Saving to: ‘../data/aclImdb_v1.tar.gz’
#
# ../data/aclImdb_v1. 100%[===================>]  80.23M  20.4MB/s    in 7.7s
#
# 2019-06-28 17:20:08 (10.4 MB/s) - ‘../data/aclImdb_v1.tar.gz’ saved [84125825/84125825]

# %% [markdown]
# ## Step 2: Preparing the data
#
# The data we have downloaded is split into various files, each of which contains a single review. It will be much easier going forward if we combine these individual files into two large files, one for training and one for testing.

# %%
import os
import glob

def read_imdb_data(data_dir='../data/aclImdb'):
    data = {}
    labels = {}
    
    for data_type in ['train', 'test']:
        data[data_type] = {}
        labels[data_type] = {}
        
        for sentiment in ['pos', 'neg']:
            data[data_type][sentiment] = []
            labels[data_type][sentiment] = []
            
            path = os.path.join(data_dir, data_type, sentiment, '*.txt')
            files = glob.glob(path)
            
            for f in files:
                with open(f) as review:
                    data[data_type][sentiment].append(review.read())
                    # Here we represent a positive review by '1' and a negative review by '0'
                    labels[data_type][sentiment].append(1 if sentiment == 'pos' else 0)
                    
            assert len(data[data_type][sentiment]) == len(labels[data_type][sentiment]), \
                    "{}/{} data size does not match labels size".format(data_type, sentiment)
                
    return data, labels

# %%
data, labels = read_imdb_data()
print("IMDB reviews: train = {} pos / {} neg, test = {} pos / {} neg".format(
            len(data['train']['pos']), len(data['train']['neg']),
            len(data['test']['pos']), len(data['test']['neg'])))
# Out:
# IMDB reviews: train = 12500 pos / 12500 neg, test = 12500 pos / 12500 neg

# %%
from sklearn.utils import shuffle

def prepare_imdb_data(data, labels):
    """Prepare training and test sets from IMDb movie reviews."""
    
    #Combine positive and negative reviews and labels
    data_train = data['train']['pos'] + data['train']['neg']
    data_test = data['test']['pos'] + data['test']['neg']
    labels_train = labels['train']['pos'] + labels['train']['neg']
    labels_test = labels['test']['pos'] + labels['test']['neg']
    
    #Shuffle reviews and corresponding labels within training and test sets
    data_train, labels_train = shuffle(data_train, labels_train)
    data_test, labels_test = shuffle(data_test, labels_test)
    
    # Return a unified training data, test data, training labels, test labets
    return data_train, data_test, labels_train, labels_test

# %%
train_X, test_X, train_y, test_y = prepare_imdb_data(data, labels)
print("IMDb reviews (combined): train = {}, test = {}".format(len(train_X), len(test_X)))
# Out:
# IMDb reviews (combined): train = 25000, test = 25000

# %%
train_X[100]
# Out:
# "I read some previous comments stating that this movie loses steam towards the end of the movie and also that it has a similar ending to Cape Fear. I completely disagree. I'm going to give a simple review for the normal moviegoers out there. I thought the casting was perfect. I thought this was one of Ed Harris's best performances. What an evil psychopath!!! I have a lot of respect for his acting after viewing his performance in this movie. I was riveted throughout this movie. If you like mystery thrillers then this definitely a movie you want to see. I also noticed a young Scarlett Johannson in this movie. This movie is filled with top stars and I highly recommend it!"

# %% [markdown]
# ## Step 3: Processing the data
#
# Now that we have our training and testing datasets merged and ready to use, we need to start processing the raw data into something that will be useable by our machine learning algorithm. To begin with, we remove any html formatting that may appear in the reviews and perform some standard natural language processing in order to homogenize the data.

# %%
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
from nltk.stem.porter import *
stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
import re
from bs4 import BeautifulSoup

def review_to_words(review):
    text = BeautifulSoup(review, "html.parser").get_text() # Remove HTML tags
    text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower()) # Convert to lower case
    words = text.split() # Split string into words
    words = [w for w in words if w not in stopwords.words("english")] # Remove stopwords
    words = [PorterStemmer().stem(w) for w in words] # stem
    
    return words

# %%
import pickle

cache_dir = os.path.join("../cache", "sentiment_analysis")  # where to store cache files
os.makedirs(cache_dir, exist_ok=True)  # ensure cache directory exists

def preprocess_data(data_train, data_test, labels_train, labels_test,
                    cache_dir=cache_dir, cache_file="preprocessed_data.pkl"):
    """Convert each review to words; read from cache if available."""

    # If cache_file is not None, try to read from it first
    cache_data = None
    if cache_file is not None:
        try:
            with open(os.path.join(cache_dir, cache_file), "rb") as f:
                cache_data = pickle.load(f)
            print("Read preprocessed data from cache file:", cache_file)
        except:
            pass  # unable to read from cache, but that's okay
    
    # If cache is missing, then do the heavy lifting
    if cache_data is None:
        # Preprocess training and test data to obtain words for each review
        #words_train = list(map(review_to_words, data_train))
        #words_test = list(map(review_to_words, data_test))
        words_train = [review_to_words(review) for review in data_train]
        words_test = [review_to_words(review) for review in data_test]
        
        # Write to cache file for future runs
        if cache_file is not None:
            cache_data = dict(words_train=words_train, words_test=words_test,
                              labels_train=labels_train, labels_test=labels_test)
            with open(os.path.join(cache_dir, cache_file), "wb") as f:
                pickle.dump(cache_data, f)
            print("Wrote preprocessed data to cache file:", cache_file)
    else:
        # Unpack data loaded from cache file
        words_train, words_test, labels_train, labels_test = (cache_data['words_train'],
                cache_data['words_test'], cache_data['labels_train'], cache_data['labels_test'])
    
    return words_train, words_test, labels_train, labels_test

# %%
# Preprocess data
train_X, test_X, train_y, test_y = preprocess_data(train_X, test_X, train_y, test_y)
# Out:
# Read preprocessed data from cache file: preprocessed_data.pkl

# %% [markdown]
# ### Extract Bag-of-Words features
#
# For the model we will be implementing, rather than using the reviews directly, we are going to transform each review into a Bag-of-Words feature representation. Keep in mind that 'in the wild' we will only have access to the training set so our transformer can only use the training set to construct a representation.

# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.externals import joblib
# joblib is an enhanced version of pickle that is more efficient for storing NumPy arrays

def extract_BoW_features(words_train, words_test, vocabulary_size=5000,
                         cache_dir=cache_dir, cache_file="bow_features.pkl"):
    """Extract Bag-of-Words for a given set of documents, already preprocessed into words."""
    
    # If cache_file is not None, try to read from it first
    cache_data = None
    if cache_file is not None:
        try:
            with open(os.path.join(cache_dir, cache_file), "rb") as f:
                cache_data = joblib.load(f)
            print("Read features from cache file:", cache_file)
        except:
            pass  # unable to read from cache, but that's okay
    
    # If cache is missing, then do the heavy lifting
    if cache_data is None:
        # Fit a vectorizer to training documents and use it to transform them
        # NOTE: Training documents have already been preprocessed and tokenized into words;
        #       pass in dummy functions to skip those steps, e.g. preprocessor=lambda x: x
        vectorizer = CountVectorizer(max_features=vocabulary_size,
                preprocessor=lambda x: x, tokenizer=lambda x: x)  # already preprocessed
        features_train = vectorizer.fit_transform(words_train).toarray()

        # Apply the same vectorizer to transform the test documents (ignore unknown words)
        features_test = vectorizer.transform(words_test).toarray()
        
        # NOTE: Remember to convert the features using .toarray() for a compact representation
        
        # Write to cache file for future runs (store vocabulary as well)
        if cache_file is not None:
            vocabulary = vectorizer.vocabulary_
            cache_data = dict(features_train=features_train, features_test=features_test,
                             vocabulary=vocabulary)
            with open(os.path.join(cache_dir, cache_file), "wb") as f:
                joblib.dump(cache_data, f)
            print("Wrote features to cache file:", cache_file)
    else:
        # Unpack data loaded from cache file
        features_train, features_test, vocabulary = (cache_data['features_train'],
                cache_data['features_test'], cache_data['vocabulary'])
    
    # Return both the extracted features as well as the vocabulary
    return features_train, features_test, vocabulary

# %%
# Extract Bag of Words features for both training and test datasets
train_X, test_X, vocabulary = extract_BoW_features(train_X, test_X)
# Out:
# Wrote features to cache file: bow_features.pkl

# %% [markdown]
# ## Step 4: Classification using XGBoost
#
# Now that we have created the feature representation of our training (and testing) data, it is time to start setting up and using the XGBoost classifier provided by SageMaker.
#
# ### Writing the dataset
#
# The XGBoost classifier that we will be using requires the dataset to be written to a file and stored using Amazon S3. To do this, we will start by splitting the training dataset into two parts, the data we will train the model with and a validation set. Then, we will write those datasets to a file and upload the files to S3. In addition, we will write the test set input to a file and upload the file to S3. This is so that we can use SageMakers Batch Transform functionality to test our model once we've fit it.

# %%
import pandas as pd

val_X = pd.DataFrame(train_X[:10000])
train_X = pd.DataFrame(train_X[10000:])

val_y = pd.DataFrame(train_y[:10000])
train_y = pd.DataFrame(train_y[10000:])

test_y = pd.DataFrame(test_y)
test_X = pd.DataFrame(test_X)

# %% [markdown]
# The documentation for the XGBoost algorithm in SageMaker requires that the saved datasets should contain no headers or index and that for the training and validation data, the label should occur first for each sample.
#
# For more information about this and other algorithms, the SageMaker developer documentation can be found on __[Amazon's website.](https://docs.aws.amazon.com/sagemaker/latest/dg/)__

# %%
# First we make sure that the local directory in which we'd like to store the training and validation csv files exists.
data_dir = '../data/xgboost'
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

# %%
# First, save the test data to test.csv in the data_dir directory. Note that we do not save the associated ground truth
# labels, instead we will use them later to compare with our model output.

pd.DataFrame(test_X).to_csv(os.path.join(data_dir, 'test.csv'), header=False, index=False)
pd.concat([val_y, val_X], axis=1).to_csv(os.path.join(data_dir, 'validation.csv'), header=False, index=False)
pd.concat([train_y, train_X], axis=1).to_csv(os.path.join(data_dir, 'train.csv'), header=False, index=False)

# %%
# To save a bit of memory we can set text_X, train_X, val_X, train_y and val_y to None.

train_X = val_X = train_y = val_y = None

# %% [markdown]
# ### Uploading Training / Validation files to S3
#
# Amazon's S3 service allows us to store files that can be access by both the built-in training models such as the XGBoost model we will be using as well as custom models such as the one we will see a little later.
#
# For this, and most other tasks we will be doing using SageMaker, there are two methods we could use. The first is to use the low level functionality of SageMaker which requires knowing each of the objects involved in the SageMaker environment. The second is to use the high level functionality in which certain choices have been made on the user's behalf. The low level approach benefits from allowing the user a great deal of flexibility while the high level approach makes development much quicker. For our purposes we will opt to use the high level approach although using the low-level approach is certainly an option.
#
# Recall the method `upload_data()` which is a member of object representing our current SageMaker session. What this method does is upload the data to the default bucket (which is created if it does not exist) into the path described by the key_prefix variable. To see this for yourself, once you have uploaded the data files, go to the S3 console and look to see where the files have been uploaded.
#
# For additional resources, see the __[SageMaker API documentation](http://sagemaker.readthedocs.io/en/latest/)__ and in addition the __[SageMaker Developer Guide.](https://docs.aws.amazon.com/sagemaker/latest/dg/)__

# %%
import sagemaker

session = sagemaker.Session() # Store the current SageMaker session

# S3 prefix (which folder will we use)
prefix = 'sentiment-xgboost'

test_location = session.upload_data(os.path.join(data_dir, 'test.csv'), key_prefix=prefix)
val_location = session.upload_data(os.path.join(data_dir, 'validation.csv'), key_prefix=prefix)
train_location = session.upload_data(os.path.join(data_dir, 'train.csv'), key_prefix=prefix)

# %% [markdown]
# ### (TODO) Creating a hypertuned XGBoost model
#
# Now that the data has been uploaded it is time to create the XGBoost model. As in the Boston Housing notebook, the first step is to create an estimator object which will be used as the *base* of your hyperparameter tuning job.

# %%
from sagemaker import get_execution_role

# Our current execution role is require when creating the model as the training
# and inference code will need to access the model artifacts.
role = get_execution_role()

# %%
# We need to retrieve the location of the container which is provided by Amazon for using XGBoost.
# As a matter of convenience, the training and inference code both use the same container.
from sagemaker.amazon.amazon_estimator import get_image_uri

container = get_image_uri(session.boto_region_name, 'xgboost')

# %%
# TODO: Create a SageMaker estimator using the container location determined in the previous cell.
#       It is recommended that you use a single training instance of type ml.m4.xlarge. It is also
#       recommended that you use 's3://{}/{}/output'.format(session.default_bucket(), prefix) as the
#       output path.

xgb = sagemaker.estimator.Estimator(container, # The location of the container we wish to use
                                    role,                                    # What is our current IAM Role
                                    train_instance_count=1,                  # How many compute instances
                                    train_instance_type='ml.m4.xlarge',      # What kind of compute instances
                                    output_path='s3://{}/{}/output'.format(session.default_bucket(), prefix),
                                    sagemaker_session=session)

# TODO: Set the XGBoost hyperparameters in the xgb object. Don't forget that in this case we have a binary
#       label so we should be using the 'binary:logistic' objective.
xgb.set_hyperparameters(max_depth=5,
                        eta=0.2,
                        gamma=4,
                        min_child_weight=6,
                        subsample=0.8,
                        silent=0,
                        objective='binary:logistic',
                        early_stopping_rounds=10,
                        num_round=500)

# %% [markdown]
# ### (TODO) Create the hyperparameter tuner
#
# Now that the base estimator has been set up we need to construct a hyperparameter tuner object which we will use to request SageMaker construct a hyperparameter tuning job.
#
# **Note:** Training a single sentiment analysis XGBoost model takes longer than training a Boston Housing XGBoost model so if you don't want the hyperparameter tuning job to take too long, make sure to not set the total number of models (jobs) too high.

# %%
# First, make sure to import the relevant objects used to construct the tuner
from sagemaker.tuner import IntegerParameter, ContinuousParameter, HyperparameterTuner

# TODO: Create the hyperparameter tuner object

xgb_hyperparameter_tuner = HyperparameterTuner(estimator = xgb, # The estimator object to use as the basis for the training jobs.
                                               objective_metric_name = 'validation:rmse', # The metric used to compare trained models.
                                               objective_type = 'Minimize', # Whether we wish to minimize or maximize the metric.
                                               max_jobs = 6, # The total number of models to train
                                               max_parallel_jobs = 3, # The number of models to train in parallel
                                               hyperparameter_ranges = {
                                                    'max_depth': IntegerParameter(3, 12),
                                                    'eta'      : ContinuousParameter(0.05, 0.5),
                                                    'min_child_weight': IntegerParameter(2, 8),
                                                    'subsample': ContinuousParameter(0.5, 0.9),
                                                    'gamma': ContinuousParameter(0, 10),
                                               })

# %% [markdown]
# ### Fit the hyperparameter tuner
#
# Now that the hyperparameter tuner object has been constructed, it is time to fit the various models and find the best performing model.

# %%
s3_input_train = sagemaker.s3_input(s3_data=train_location, content_type='csv')
s3_input_validation = sagemaker.s3_input(s3_data=val_location, content_type='csv')

# %%
xgb_hyperparameter_tuner.fit({'train': s3_input_train, 'validation': s3_input_validation})

# %% [markdown]
# Remember that the tuning job is constructed and run in the background so if we want to see the progress of our training job we need to call the `wait()` method.

# %%
xgb_hyperparameter_tuner.wait()
# Out:
# ...........................................................................................................................................................................................................................................................................................................................................................................!

# %% [markdown]
# ### (TODO) Testing the model
#
# Now that we've run our hyperparameter tuning job, it's time to see how well the best performing model actually performs. To do this we will use SageMaker's Batch Transform functionality. Batch Transform is a convenient way to perform inference on a large dataset in a way that is not realtime. That is, we don't necessarily need to use our model's results immediately and instead we can peform inference on a large number of samples. An example of this in industry might be peforming an end of month report. This method of inference can also be useful to us as it means to can perform inference on our entire test set.
#
# Remember that in order to create a transformer object to perform the batch transform job, we need a trained estimator object. We can do that using the `attach()` method, creating an estimator object which is attached to the best trained job.

# %%
# TODO: Create a new estimator object attached to the best training job found during hyperparameter tuning

xgb_attached = sagemaker.estimator.Estimator.attach(xgb_hyperparameter_tuner.best_training_job())
# Out:
# 2019-06-30 00:31:47 Starting - Preparing the instances for training
# 2019-06-30 00:31:47 Downloading - Downloading input data
# 2019-06-30 00:31:47 Training - Training image download completed. Training in progress.
# 2019-06-30 00:31:47 Uploading - Uploading generated training model
# 2019-06-30 00:31:47 Completed - Training job completedArguments: train
# [2019-06-30:00:23:36:INFO] Running standalone xgboost training.
# [2019-06-30:00:23:36:INFO] Setting up HPO optimized metric to be : rmse
# [2019-06-30:00:23:36:INFO] File size need to be processed in the node: 238.47mb. Available memory size in the node: 8454.39mb
# [2019-06-30:00:23:36:INFO] Determined delimiter of CSV input is ','
# [00:23:36] S3DistributionType set as FullyReplicated
# [00:23:38] 15000x5000 matrix with 75000000 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2019-06-30:00:23:38:INFO] Determined delimiter of CSV input is ','
# [00:23:38] S3DistributionType set as FullyReplicated
# [00:23:39] 10000x5000 matrix with 50000000 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [00:23:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [0]#011train-rmse:0.484139#011validation-rmse:0.484713
# Multiple eval metrics have been passed: 'validation-rmse' will be used for early stopping.
#
# Will train until validation-rmse hasn't improved in 10 rounds.
# [00:23:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [1]#011train-rmse:0.473328#011validation-rmse:0.474151
# [00:23:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [2]#011train-rmse:0.464942#011validation-rmse:0.465979
# [00:23:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [3]#011train-rmse:0.457591#011validation-rmse:0.458958
# [00:23:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [4]#011train-rmse:0.451827#011validation-rmse:0.453482
# [00:23:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [5]#011train-rmse:0.447078#011validation-rmse:0.448945
# [00:23:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [6]#011train-rmse:0.442411#011validation-rmse:0.444238
# [00:23:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [7]#011train-rmse:0.438289#011validation-rmse:0.440234
# [00:23:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [8]#011train-rmse:0.434173#011validation-rmse:0.436442
# [00:23:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [9]#011train-rmse:0.430637#011validation-rmse:0.433245
# [00:23:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [10]#011train-rmse:0.427447#011validation-rmse:0.430281
# [00:23:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11]#011train-rmse:0.42388#011validation-rmse:0.426872
# [00:23:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [12]#011train-rmse:0.421269#011validation-rmse:0.424275
# [00:23:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [13]#011train-rmse:0.418228#011validation-rmse:0.421409
# [00:23:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [14]#011train-rmse:0.416028#011validation-rmse:0.419147
# [00:23:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [15]#011train-rmse:0.413488#011validation-rmse:0.416978
# [00:23:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [16]#011train-rmse:0.411016#011validation-rmse:0.41474
# [00:23:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [17]#011train-rmse:0.4088#011validation-rmse:0.412679
# [00:24:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [18]#011train-rmse:0.406465#011validation-rmse:0.410388
# [00:24:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [19]#011train-rmse:0.40439#011validation-rmse:0.408075
# [00:24:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [20]#011train-rmse:0.402162#011validation-rmse:0.405781
# [00:24:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [21]#011train-rmse:0.39996#011validation-rmse:0.403949
# [00:24:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [22]#011train-rmse:0.397899#011validation-rmse:0.402056
# [00:24:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [23]#011train-rmse:0.396082#011validation-rmse:0.400301
# [00:24:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [24]#011train-rmse:0.394326#011validation-rmse:0.399058
# [00:24:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [25]#011train-rmse:0.392675#011validation-rmse:0.397587
# [00:24:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [26]#011train-rmse:0.390646#011validation-rmse:0.39597
# [00:24:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [27]#011train-rmse:0.389266#011validation-rmse:0.394683
# [00:24:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [28]#011train-rmse:0.387717#011validation-rmse:0.393234
# [00:24:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [29]#011train-rmse:0.386316#011validation-rmse:0.392093
# [00:24:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [30]#011train-rmse:0.385057#011validation-rmse:0.391117
# [00:24:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [31]#011train-rmse:0.383734#011validation-rmse:0.389957
# [00:24:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [32]#011train-rmse:0.382123#011validation-rmse:0.388321
# [00:24:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [33]#011train-rmse:0.380902#011validation-rmse:0.387298
# [00:24:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=3
# [34]#011train-rmse:0.379752#011validation-rmse:0.386146
# [00:24:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [35]#011train-rmse:0.378664#011validation-rmse:0.384956
# [00:24:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [36]#011train-rmse:0.377476#011validation-rmse:0.383917
# [00:24:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [37]#011train-rmse:0.376256#011validation-rmse:0.382869
# [00:24:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=3
# [38]#011train-rmse:0.375016#011validation-rmse:0.381669
# [00:24:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [39]#011train-rmse:0.373716#011validation-rmse:0.380569
# [00:24:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [40]#011train-rmse:0.372399#011validation-rmse:0.379213
# [00:24:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [41]#011train-rmse:0.370928#011validation-rmse:0.377979
# [00:24:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [42]#011train-rmse:0.369692#011validation-rmse:0.376821
# [00:24:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=3
# [43]#011train-rmse:0.368517#011validation-rmse:0.375875
# [00:24:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [44]#011train-rmse:0.367262#011validation-rmse:0.374755
# [00:24:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [45]#011train-rmse:0.366193#011validation-rmse:0.373954
# [00:24:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [46]#011train-rmse:0.365253#011validation-rmse:0.373084
# [00:24:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [47]#011train-rmse:0.364381#011validation-rmse:0.372168
# [00:24:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=3
# [48]#011train-rmse:0.363535#011validation-rmse:0.371366
# [00:24:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [49]#011train-rmse:0.362859#011validation-rmse:0.370959
# [00:24:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [50]#011train-rmse:0.361956#011validation-rmse:0.370145
# [00:24:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [51]#011train-rmse:0.360976#011validation-rmse:0.369199
# [00:24:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [52]#011train-rmse:0.36#011validation-rmse:0.368465
# [00:24:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [53]#011train-rmse:0.358808#011validation-rmse:0.367772
# [00:24:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [54]#011train-rmse:0.357856#011validation-rmse:0.366996
# [00:24:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=3
# [55]#011train-rmse:0.35723#011validation-rmse:0.366248
# [00:24:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [56]#011train-rmse:0.356223#011validation-rmse:0.365521
# [00:24:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [57]#011train-rmse:0.355321#011validation-rmse:0.365117
# [00:24:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=3
# [58]#011train-rmse:0.354681#011validation-rmse:0.364821
# [00:24:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=3
# [59]#011train-rmse:0.354015#011validation-rmse:0.364313
# [00:24:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [60]#011train-rmse:0.352856#011validation-rmse:0.363345
# [00:24:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [61]#011train-rmse:0.352003#011validation-rmse:0.362652
# [00:24:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [62]#011train-rmse:0.351167#011validation-rmse:0.362212
# [00:24:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [63]#011train-rmse:0.350312#011validation-rmse:0.361595
# [00:24:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [64]#011train-rmse:0.349664#011validation-rmse:0.361155
# [00:24:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [65]#011train-rmse:0.348854#011validation-rmse:0.360513
# [00:24:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [66]#011train-rmse:0.348142#011validation-rmse:0.360026
# [00:24:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=3
# [67]#011train-rmse:0.347523#011validation-rmse:0.359432
# [00:24:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [68]#011train-rmse:0.346723#011validation-rmse:0.358774
# [00:24:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [69]#011train-rmse:0.346086#011validation-rmse:0.358152
# [00:24:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [70]#011train-rmse:0.345261#011validation-rmse:0.35765
# [00:24:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [71]#011train-rmse:0.34467#011validation-rmse:0.357038
# [00:24:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=3
# [72]#011train-rmse:0.344025#011validation-rmse:0.356521
# [00:24:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [73]#011train-rmse:0.34323#011validation-rmse:0.355833
# [00:24:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [74]#011train-rmse:0.342598#011validation-rmse:0.355239
# [00:24:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [75]#011train-rmse:0.342018#011validation-rmse:0.354964
# [00:24:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [76]#011train-rmse:0.341201#011validation-rmse:0.35419
# [00:24:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [77]#011train-rmse:0.340485#011validation-rmse:0.353427
# [00:24:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [78]#011train-rmse:0.339709#011validation-rmse:0.352768
# [00:24:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [79]#011train-rmse:0.339081#011validation-rmse:0.352187
# [00:25:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [80]#011train-rmse:0.338511#011validation-rmse:0.351597
# [00:25:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [81]#011train-rmse:0.33793#011validation-rmse:0.351205
# [00:25:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [82]#011train-rmse:0.337476#011validation-rmse:0.350764
# [00:25:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [83]#011train-rmse:0.336648#011validation-rmse:0.350391
# [00:25:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [84]#011train-rmse:0.33607#011validation-rmse:0.349991
# [00:25:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [85]#011train-rmse:0.33539#011validation-rmse:0.349548
# [00:25:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [86]#011train-rmse:0.334704#011validation-rmse:0.349101
# [00:25:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [87]#011train-rmse:0.33414#011validation-rmse:0.348696
# [00:25:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [88]#011train-rmse:0.333508#011validation-rmse:0.348117
# [00:25:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [89]#011train-rmse:0.333045#011validation-rmse:0.347814
# [00:25:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=3
# [90]#011train-rmse:0.332575#011validation-rmse:0.347332
# [00:25:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [91]#011train-rmse:0.332187#011validation-rmse:0.346832
# [00:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=3
# [92]#011train-rmse:0.331735#011validation-rmse:0.346521
# [00:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [93]#011train-rmse:0.330987#011validation-rmse:0.346153
# [00:25:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [94]#011train-rmse:0.330353#011validation-rmse:0.3458
# [00:25:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=3
# [95]#011train-rmse:0.329779#011validation-rmse:0.345576
# [00:25:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [96]#011train-rmse:0.329128#011validation-rmse:0.345027
# [00:25:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [97]#011train-rmse:0.328481#011validation-rmse:0.344465
# [00:25:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [98]#011train-rmse:0.327904#011validation-rmse:0.344003
# [00:25:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [99]#011train-rmse:0.327419#011validation-rmse:0.343721
# [00:25:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [100]#011train-rmse:0.326762#011validation-rmse:0.34335
# [00:25:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [101]#011train-rmse:0.326308#011validation-rmse:0.342876
# [00:25:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [102]#011train-rmse:0.325816#011validation-rmse:0.342657
# [00:25:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=3
# [103]#011train-rmse:0.325321#011validation-rmse:0.342346
# [00:25:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 8 pruned nodes, max_depth=3
# [104]#011train-rmse:0.324976#011validation-rmse:0.342106
# [00:25:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [105]#011train-rmse:0.324372#011validation-rmse:0.341696
# [00:25:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=3
# [106]#011train-rmse:0.323794#011validation-rmse:0.341276
# [00:25:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [107]#011train-rmse:0.323273#011validation-rmse:0.340987
# [00:25:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [108]#011train-rmse:0.32289#011validation-rmse:0.340833
# [00:25:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [109]#011train-rmse:0.322528#011validation-rmse:0.340566
# [00:25:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [110]#011train-rmse:0.3221#011validation-rmse:0.340167
# [00:25:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [111]#011train-rmse:0.321752#011validation-rmse:0.340091
# [00:25:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=3
# [112]#011train-rmse:0.321217#011validation-rmse:0.339866
# [00:25:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [113]#011train-rmse:0.320813#011validation-rmse:0.33956
# [00:25:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [114]#011train-rmse:0.320351#011validation-rmse:0.33926
# [00:25:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [115]#011train-rmse:0.319956#011validation-rmse:0.339018
# [00:25:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [116]#011train-rmse:0.319565#011validation-rmse:0.338721
# [00:25:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [117]#011train-rmse:0.319223#011validation-rmse:0.338525
# [00:25:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [118]#011train-rmse:0.318839#011validation-rmse:0.337993
# [00:25:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [119]#011train-rmse:0.318359#011validation-rmse:0.337603
# [00:25:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [120]#011train-rmse:0.317943#011validation-rmse:0.337189
# [00:25:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [121]#011train-rmse:0.317391#011validation-rmse:0.336988
# [00:25:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [122]#011train-rmse:0.316952#011validation-rmse:0.336824
# [00:25:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=3
# [123]#011train-rmse:0.316583#011validation-rmse:0.336583
# [00:25:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [124]#011train-rmse:0.316293#011validation-rmse:0.336365
# [00:25:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [125]#011train-rmse:0.315741#011validation-rmse:0.336091
# [00:25:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [126]#011train-rmse:0.315323#011validation-rmse:0.3359
# [00:25:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [127]#011train-rmse:0.314942#011validation-rmse:0.335737
# [00:25:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [128]#011train-rmse:0.314395#011validation-rmse:0.335426
# [00:25:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=3
# [129]#011train-rmse:0.314038#011validation-rmse:0.335331
# [00:25:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [130]#011train-rmse:0.313627#011validation-rmse:0.334826
# [00:25:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [131]#011train-rmse:0.3131#011validation-rmse:0.334598
# [00:25:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [132]#011train-rmse:0.312646#011validation-rmse:0.334203
# [00:25:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [133]#011train-rmse:0.312351#011validation-rmse:0.333958
# [00:25:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [134]#011train-rmse:0.311966#011validation-rmse:0.333825
# [00:25:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=3
# [135]#011train-rmse:0.311599#011validation-rmse:0.333728
# [00:25:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [136]#011train-rmse:0.311317#011validation-rmse:0.333327
# [00:25:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [137]#011train-rmse:0.310988#011validation-rmse:0.333173
# [00:25:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [138]#011train-rmse:0.310707#011validation-rmse:0.333142
# [00:25:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [139]#011train-rmse:0.31034#011validation-rmse:0.332957
# [00:25:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [140]#011train-rmse:0.309882#011validation-rmse:0.33258
# [00:25:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [141]#011train-rmse:0.309569#011validation-rmse:0.332398
# [00:25:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [142]#011train-rmse:0.30922#011validation-rmse:0.332068
# [00:26:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=3
# [143]#011train-rmse:0.308684#011validation-rmse:0.33172
# [00:26:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [144]#011train-rmse:0.308314#011validation-rmse:0.331511
# [00:26:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [145]#011train-rmse:0.307947#011validation-rmse:0.331249
# [00:26:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [146]#011train-rmse:0.30762#011validation-rmse:0.331185
# [00:26:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=3
# [147]#011train-rmse:0.307324#011validation-rmse:0.331149
# [00:26:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=3
# [148]#011train-rmse:0.306944#011validation-rmse:0.33081
# [00:26:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 8 pruned nodes, max_depth=3
# [149]#011train-rmse:0.30665#011validation-rmse:0.330739
# [00:26:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [150]#011train-rmse:0.306343#011validation-rmse:0.33059
# [00:26:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [151]#011train-rmse:0.306077#011validation-rmse:0.330396
# [00:26:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [152]#011train-rmse:0.30563#011validation-rmse:0.330064
# [00:26:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=3
# [153]#011train-rmse:0.305254#011validation-rmse:0.329829
# [00:26:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [154]#011train-rmse:0.304928#011validation-rmse:0.329782
# [00:26:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [155]#011train-rmse:0.30456#011validation-rmse:0.329708
# [00:26:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [156]#011train-rmse:0.304264#011validation-rmse:0.32957
# [00:26:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [157]#011train-rmse:0.303983#011validation-rmse:0.329196
# [00:26:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [158]#011train-rmse:0.303635#011validation-rmse:0.32891
# [00:26:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [159]#011train-rmse:0.303255#011validation-rmse:0.328747
# [00:26:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [160]#011train-rmse:0.303063#011validation-rmse:0.328643
# [00:26:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [161]#011train-rmse:0.302849#011validation-rmse:0.328509
# [00:26:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [162]#011train-rmse:0.30267#011validation-rmse:0.328334
# [00:26:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=3
# [163]#011train-rmse:0.302384#011validation-rmse:0.328211
# [00:26:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [164]#011train-rmse:0.302017#011validation-rmse:0.327989
# [00:26:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=3
# [165]#011train-rmse:0.301712#011validation-rmse:0.328076
# [00:26:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [166]#011train-rmse:0.301408#011validation-rmse:0.32801
# [00:26:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [167]#011train-rmse:0.301077#011validation-rmse:0.327765
# [00:26:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [168]#011train-rmse:0.300763#011validation-rmse:0.327654
# [00:26:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [169]#011train-rmse:0.300482#011validation-rmse:0.327543
# [00:26:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=3
# [170]#011train-rmse:0.300191#011validation-rmse:0.327259
# [00:26:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [171]#011train-rmse:0.299922#011validation-rmse:0.327181
# [00:26:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [172]#011train-rmse:0.299614#011validation-rmse:0.326934
# [00:26:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [173]#011train-rmse:0.29929#011validation-rmse:0.326824
# [00:26:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [174]#011train-rmse:0.299036#011validation-rmse:0.326665
# [00:26:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [175]#011train-rmse:0.298713#011validation-rmse:0.326533
# [00:26:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [176]#011train-rmse:0.298478#011validation-rmse:0.326433
# [00:26:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [177]#011train-rmse:0.298225#011validation-rmse:0.326237
# [00:26:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [178]#011train-rmse:0.297762#011validation-rmse:0.326133
# [00:26:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [179]#011train-rmse:0.297456#011validation-rmse:0.326145
# [00:26:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [180]#011train-rmse:0.297168#011validation-rmse:0.325871
# [00:26:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [181]#011train-rmse:0.296899#011validation-rmse:0.325676
# [00:26:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [182]#011train-rmse:0.296583#011validation-rmse:0.32554
# [00:26:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [183]#011train-rmse:0.296394#011validation-rmse:0.32532
# [00:26:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [184]#011train-rmse:0.296196#011validation-rmse:0.325159
# [00:26:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [185]#011train-rmse:0.295812#011validation-rmse:0.325077
# [00:26:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [186]#011train-rmse:0.295595#011validation-rmse:0.324993
# [00:26:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [187]#011train-rmse:0.295417#011validation-rmse:0.324801
# [00:26:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [188]#011train-rmse:0.295169#011validation-rmse:0.324657
# [00:26:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [189]#011train-rmse:0.29492#011validation-rmse:0.32468
# [00:26:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [190]#011train-rmse:0.294589#011validation-rmse:0.32452
# [00:26:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=3
# [191]#011train-rmse:0.294407#011validation-rmse:0.324404
# [00:26:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [192]#011train-rmse:0.294147#011validation-rmse:0.324333
# [00:26:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 8 pruned nodes, max_depth=3
# [193]#011train-rmse:0.293974#011validation-rmse:0.324177
# [00:26:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [194]#011train-rmse:0.293787#011validation-rmse:0.324068
# [00:26:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [195]#011train-rmse:0.293584#011validation-rmse:0.323839
# [00:26:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [196]#011train-rmse:0.293248#011validation-rmse:0.323668
# [00:26:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [197]#011train-rmse:0.293028#011validation-rmse:0.323506
# [00:26:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [198]#011train-rmse:0.292748#011validation-rmse:0.323463
# [00:26:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [199]#011train-rmse:0.292494#011validation-rmse:0.323447
# [00:26:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [200]#011train-rmse:0.292223#011validation-rmse:0.32319
# [00:26:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=3
# [201]#011train-rmse:0.291949#011validation-rmse:0.323185
# [00:26:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [202]#011train-rmse:0.291707#011validation-rmse:0.32323
# [00:26:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [203]#011train-rmse:0.291583#011validation-rmse:0.323053
# [00:26:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [204]#011train-rmse:0.291355#011validation-rmse:0.322858
# [00:27:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [205]#011train-rmse:0.290906#011validation-rmse:0.322676
# [00:27:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [206]#011train-rmse:0.290664#011validation-rmse:0.322543
# [00:27:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [207]#011train-rmse:0.290388#011validation-rmse:0.322376
# [00:27:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [208]#011train-rmse:0.290144#011validation-rmse:0.322166
# [00:27:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=3
# [209]#011train-rmse:0.289949#011validation-rmse:0.321968
# [00:27:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [210]#011train-rmse:0.289705#011validation-rmse:0.321725
# [00:27:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [211]#011train-rmse:0.289485#011validation-rmse:0.321616
# [00:27:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [212]#011train-rmse:0.28927#011validation-rmse:0.321578
# [00:27:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=3
# [213]#011train-rmse:0.28902#011validation-rmse:0.321495
# [00:27:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [214]#011train-rmse:0.288763#011validation-rmse:0.321249
# [00:27:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=3
# [215]#011train-rmse:0.288572#011validation-rmse:0.32104
# [00:27:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [216]#011train-rmse:0.288311#011validation-rmse:0.320723
# [00:27:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [217]#011train-rmse:0.288031#011validation-rmse:0.320591
# [00:27:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [218]#011train-rmse:0.287779#011validation-rmse:0.320309
# [00:27:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [219]#011train-rmse:0.287591#011validation-rmse:0.320362
# [00:27:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [220]#011train-rmse:0.287361#011validation-rmse:0.320189
# [00:27:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=3
# [221]#011train-rmse:0.287057#011validation-rmse:0.320017
# [00:27:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [222]#011train-rmse:0.286757#011validation-rmse:0.31986
# [00:27:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [223]#011train-rmse:0.286593#011validation-rmse:0.319708
# [00:27:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [224]#011train-rmse:0.286373#011validation-rmse:0.319657
# [00:27:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=3
# [225]#011train-rmse:0.286068#011validation-rmse:0.319486
# [00:27:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [226]#011train-rmse:0.285898#011validation-rmse:0.319448
# [00:27:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [227]#011train-rmse:0.28578#011validation-rmse:0.319255
# [00:27:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [228]#011train-rmse:0.285619#011validation-rmse:0.319131
# [00:27:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [229]#011train-rmse:0.285283#011validation-rmse:0.318995
# [00:27:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [230]#011train-rmse:0.285069#011validation-rmse:0.318838
# [00:27:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [231]#011train-rmse:0.284879#011validation-rmse:0.318672
# [00:27:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [232]#011train-rmse:0.284642#011validation-rmse:0.318431
# [00:27:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [233]#011train-rmse:0.284463#011validation-rmse:0.318407
# [00:27:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [234]#011train-rmse:0.284316#011validation-rmse:0.318236
# [00:27:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [235]#011train-rmse:0.284102#011validation-rmse:0.318065
# [00:27:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [236]#011train-rmse:0.283937#011validation-rmse:0.317807
# [00:27:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [237]#011train-rmse:0.283725#011validation-rmse:0.317657
# [00:27:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [238]#011train-rmse:0.283578#011validation-rmse:0.317524
# [00:27:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [239]#011train-rmse:0.283286#011validation-rmse:0.317529
# [00:27:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [240]#011train-rmse:0.282997#011validation-rmse:0.317405
# [00:27:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [241]#011train-rmse:0.282797#011validation-rmse:0.317301
# [00:27:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [242]#011train-rmse:0.282425#011validation-rmse:0.317202
# [00:27:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [243]#011train-rmse:0.282155#011validation-rmse:0.317109
# [00:27:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [244]#011train-rmse:0.282036#011validation-rmse:0.317141
# [00:27:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [245]#011train-rmse:0.281834#011validation-rmse:0.317043
# [00:27:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=3
# [246]#011train-rmse:0.281538#011validation-rmse:0.31683
# [00:27:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [247]#011train-rmse:0.281262#011validation-rmse:0.316646
# [00:27:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [248]#011train-rmse:0.281023#011validation-rmse:0.316552
# [00:27:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [249]#011train-rmse:0.280846#011validation-rmse:0.316381
# [00:27:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [250]#011train-rmse:0.280664#011validation-rmse:0.316438
# [00:27:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=3
# [251]#011train-rmse:0.280316#011validation-rmse:0.316495
# [00:27:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=3
# [252]#011train-rmse:0.280154#011validation-rmse:0.316335
# [00:27:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [253]#011train-rmse:0.280025#011validation-rmse:0.31625
# [00:27:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [254]#011train-rmse:0.279901#011validation-rmse:0.316362
# [00:27:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [255]#011train-rmse:0.279672#011validation-rmse:0.316296
# [00:27:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [256]#011train-rmse:0.279549#011validation-rmse:0.316157
# [00:27:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [257]#011train-rmse:0.279272#011validation-rmse:0.316329
# [00:27:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=3
# [258]#011train-rmse:0.279068#011validation-rmse:0.31646
# [00:27:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [259]#011train-rmse:0.278871#011validation-rmse:0.316334
# [00:27:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [260]#011train-rmse:0.278586#011validation-rmse:0.316198
# [00:27:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=3
# [261]#011train-rmse:0.27835#011validation-rmse:0.316019
# [00:27:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [262]#011train-rmse:0.278063#011validation-rmse:0.315976
# [00:27:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [263]#011train-rmse:0.277925#011validation-rmse:0.315927
# [00:27:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [264]#011train-rmse:0.277686#011validation-rmse:0.315939
# [00:27:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [265]#011train-rmse:0.277481#011validation-rmse:0.315937
# [00:27:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=3
# [266]#011train-rmse:0.277195#011validation-rmse:0.315855
# [00:27:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [267]#011train-rmse:0.276858#011validation-rmse:0.315657
# [00:28:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [268]#011train-rmse:0.276709#011validation-rmse:0.315482
# [00:28:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [269]#011train-rmse:0.276479#011validation-rmse:0.315408
# [00:28:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=3
# [270]#011train-rmse:0.276257#011validation-rmse:0.315255
# [00:28:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [271]#011train-rmse:0.276148#011validation-rmse:0.315306
# [00:28:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [272]#011train-rmse:0.275989#011validation-rmse:0.315496
# [00:28:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [273]#011train-rmse:0.275822#011validation-rmse:0.315437
# [00:28:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [274]#011train-rmse:0.27568#011validation-rmse:0.315438
# [00:28:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [275]#011train-rmse:0.275507#011validation-rmse:0.315302
# [00:28:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [276]#011train-rmse:0.275326#011validation-rmse:0.31532
# [00:28:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [277]#011train-rmse:0.275173#011validation-rmse:0.315171
# ...
# [401]#011train-rmse:0.257387#011validation-rmse:0.30757
# [00:30:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [402]#011train-rmse:0.257296#011validation-rmse:0.307413
# [00:30:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [403]#011train-rmse:0.257166#011validation-rmse:0.307373
# [00:30:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [404]#011train-rmse:0.25702#011validation-rmse:0.307322
# [00:30:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=3
# [405]#011train-rmse:0.256901#011validation-rmse:0.307221
# [00:30:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [406]#011train-rmse:0.256727#011validation-rmse:0.30721
# [00:30:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [407]#011train-rmse:0.256629#011validation-rmse:0.307241
# [00:30:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=3
# [408]#011train-rmse:0.256333#011validation-rmse:0.307258
# [00:30:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=3
# [409]#011train-rmse:0.256181#011validation-rmse:0.307113
# [00:30:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [410]#011train-rmse:0.256056#011validation-rmse:0.307068
# [00:30:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [411]#011train-rmse:0.256012#011validation-rmse:0.307043
# [00:30:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [412]#011train-rmse:0.255895#011validation-rmse:0.307037
# [00:30:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [413]#011train-rmse:0.255778#011validation-rmse:0.307113
# [00:30:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [414]#011train-rmse:0.25571#011validation-rmse:0.307101
# [00:30:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [415]#011train-rmse:0.255609#011validation-rmse:0.307112
# [00:30:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [416]#011train-rmse:0.255514#011validation-rmse:0.30698
# [00:30:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [417]#011train-rmse:0.255441#011validation-rmse:0.307067
# [00:30:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [418]#011train-rmse:0.255345#011validation-rmse:0.307019
# [00:30:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [419]#011train-rmse:0.255233#011validation-rmse:0.306857
# [00:30:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [420]#011train-rmse:0.255053#011validation-rmse:0.306766
# [00:30:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [421]#011train-rmse:0.25488#011validation-rmse:0.306871
# [00:30:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [422]#011train-rmse:0.254785#011validation-rmse:0.306809
# [00:30:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [423]#011train-rmse:0.254725#011validation-rmse:0.306859
# [00:30:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [424]#011train-rmse:0.254623#011validation-rmse:0.306817
# [00:30:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [425]#011train-rmse:0.25448#011validation-rmse:0.306696
# [00:30:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [426]#011train-rmse:0.254385#011validation-rmse:0.306745
# [00:30:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [427]#011train-rmse:0.254287#011validation-rmse:0.306638
# [00:30:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [428]#011train-rmse:0.254196#011validation-rmse:0.306648
# [00:30:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [429]#011train-rmse:0.254108#011validation-rmse:0.306435
# [00:30:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [430]#011train-rmse:0.253984#011validation-rmse:0.306527
# [00:30:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [431]#011train-rmse:0.253807#011validation-rmse:0.306509
# [00:30:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [432]#011train-rmse:0.253675#011validation-rmse:0.3064
# [00:30:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=3
# [433]#011train-rmse:0.253518#011validation-rmse:0.306269
# [00:30:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [434]#011train-rmse:0.253363#011validation-rmse:0.306155
# [00:30:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [435]#011train-rmse:0.253157#011validation-rmse:0.306159
# [00:30:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=3
# [436]#011train-rmse:0.253008#011validation-rmse:0.306129
# [00:30:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [437]#011train-rmse:0.252857#011validation-rmse:0.306147
# [00:30:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [438]#011train-rmse:0.252835#011validation-rmse:0.306195
# [00:30:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [439]#011train-rmse:0.252719#011validation-rmse:0.306117
# [00:30:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [440]#011train-rmse:0.252559#011validation-rmse:0.306102
# [00:30:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [441]#011train-rmse:0.252471#011validation-rmse:0.306054
# [00:30:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [442]#011train-rmse:0.252271#011validation-rmse:0.30593
# [00:30:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [443]#011train-rmse:0.252131#011validation-rmse:0.30592
# [00:30:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=3
# [444]#011train-rmse:0.251955#011validation-rmse:0.305861
# [00:30:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [445]#011train-rmse:0.251849#011validation-rmse:0.305869
# [00:30:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=3
# [446]#011train-rmse:0.251715#011validation-rmse:0.305974
# [00:30:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [447]#011train-rmse:0.251541#011validation-rmse:0.306049
# [00:30:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [448]#011train-rmse:0.251456#011validation-rmse:0.306013
# [00:30:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [449]#011train-rmse:0.251341#011validation-rmse:0.305945
# [00:30:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [450]#011train-rmse:0.251111#011validation-rmse:0.305813
# [00:30:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [451]#011train-rmse:0.251047#011validation-rmse:0.305772
# [00:30:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [452]#011train-rmse:0.250858#011validation-rmse:0.305688
# [00:30:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=3
# [453]#011train-rmse:0.25074#011validation-rmse:0.305672
# [00:30:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [454]#011train-rmse:0.250477#011validation-rmse:0.305593
# [00:30:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [455]#011train-rmse:0.250346#011validation-rmse:0.305599
# [00:30:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [456]#011train-rmse:0.25014#011validation-rmse:0.305362
# [00:31:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [457]#011train-rmse:0.250019#011validation-rmse:0.305284
# [00:31:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [458]#011train-rmse:0.249885#011validation-rmse:0.305339
# [00:31:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [459]#011train-rmse:0.249836#011validation-rmse:0.305213
# [00:31:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [460]#011train-rmse:0.249754#011validation-rmse:0.305158
# [00:31:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [461]#011train-rmse:0.249693#011validation-rmse:0.305143
# [00:31:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=3
# [462]#011train-rmse:0.249547#011validation-rmse:0.305155
# [00:31:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [463]#011train-rmse:0.249435#011validation-rmse:0.305122
# [00:31:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [464]#011train-rmse:0.249333#011validation-rmse:0.305016
# [00:31:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [465]#011train-rmse:0.249223#011validation-rmse:0.305001
# [00:31:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [466]#011train-rmse:0.249134#011validation-rmse:0.305098
# [00:31:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [467]#011train-rmse:0.249039#011validation-rmse:0.305074
# [00:31:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [468]#011train-rmse:0.248905#011validation-rmse:0.305098
# [00:31:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [469]#011train-rmse:0.248814#011validation-rmse:0.305082
# [00:31:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [470]#011train-rmse:0.248766#011validation-rmse:0.305086
# [00:31:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [471]#011train-rmse:0.248664#011validation-rmse:0.304963
# [00:31:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [472]#011train-rmse:0.248597#011validation-rmse:0.304868
# [00:31:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=3
# [473]#011train-rmse:0.248396#011validation-rmse:0.304872
# [00:31:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [474]#011train-rmse:0.248318#011validation-rmse:0.304873
# [00:31:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [475]#011train-rmse:0.248158#011validation-rmse:0.304806
# [00:31:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [476]#011train-rmse:0.2481#011validation-rmse:0.304758
# [00:31:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [477]#011train-rmse:0.247986#011validation-rmse:0.304742
# [00:31:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=3
# [478]#011train-rmse:0.24785#011validation-rmse:0.304686
# [00:31:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [479]#011train-rmse:0.247698#011validation-rmse:0.304661
# [00:31:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [480]#011train-rmse:0.247587#011validation-rmse:0.304613
# [00:31:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [481]#011train-rmse:0.247538#011validation-rmse:0.304591
# [00:31:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [482]#011train-rmse:0.247452#011validation-rmse:0.304491
# [00:31:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [483]#011train-rmse:0.247408#011validation-rmse:0.304433
# [00:31:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [484]#011train-rmse:0.247286#011validation-rmse:0.304312
# [00:31:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [485]#011train-rmse:0.247172#011validation-rmse:0.3043
# [00:31:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [486]#011train-rmse:0.247013#011validation-rmse:0.304406
# [00:31:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [487]#011train-rmse:0.246929#011validation-rmse:0.304422
# [00:31:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [488]#011train-rmse:0.246819#011validation-rmse:0.304439
# [00:31:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [489]#011train-rmse:0.246735#011validation-rmse:0.30448
# [00:31:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [490]#011train-rmse:0.246584#011validation-rmse:0.304527
# [00:31:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [491]#011train-rmse:0.246544#011validation-rmse:0.304457
# [00:31:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [492]#011train-rmse:0.246447#011validation-rmse:0.304571
# [00:31:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [493]#011train-rmse:0.246341#011validation-rmse:0.304668
# [00:31:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [494]#011train-rmse:0.246282#011validation-rmse:0.304623
# [00:31:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [495]#011train-rmse:0.246195#011validation-rmse:0.304677
# Stopping. Best iteration:
# [485]#011train-rmse:0.247172#011validation-rmse:0.3043
#
# Billable seconds: 531

# %% [markdown]
# Now that we have an estimator object attached to the correct training job, we can proceed as we normally would and create a transformer object.

# %%
# TODO: Create a transformer object from the attached estimator. Using an instance count of 1 and an instance type of ml.m4.xlarge
#       should be more than enough.

xgb_transformer = xgb_attached.transformer(instance_count = 1, instance_type = 'ml.m4.xlarge')

# %% [markdown]
# Next we actually perform the transform job. When doing so we need to make sure to specify the type of data we are sending so that it is serialized correctly in the background. In our case we are providing our model with csv data so we specify `text/csv`. Also, if the test data that we have provided is too large to process all at once then we need to specify how the data file should be split up. Since each line is a single entry in our data set we tell SageMaker that it can split the input on each line.

# %%
xgb_transformer.transform(test_location, content_type='text/csv', split_type='Line')

# %% [markdown]
# Currently the transform job is running but it is doing so in the background. Since we wish to wait until the transform job is done and we would like a bit of feedback we can run the `wait()` method.

# %%
xgb_transformer.wait()
# Out:
# *
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-41dd6a2aa41e> in <module>()
# ----> 1 xgb_transformer.wait()
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/transformer.py in wait(self)
#     164     def wait(self):
#     165         self._ensure_last_transform_job()
# --> 166         self.latest_transform_job.wait()
#     167
#     168     def _ensure_last_transform_job(self):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/transformer.py in wait(self)
#     241
#     242     def wait(self):
# --> 243         self.sagemaker_session.wait_for_transform_job(self.job_name)
#     244
#     245     @staticmethod
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/session.py in wait_for_transform_job(self, job, poll)
#     904         """
#     905         desc = _wait_until(lambda: _transform_job_status(self.sagemaker_client, job), poll)
# --> 906         self._check_job_status(job, desc, 'TransformJobStatus')
#     907         return desc
#     908
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/session.py in _check_job_status(self, job, desc, status_key_name)
#     926             reason = desc.get('FailureReason', '(No reason provided)')
#     927             job_type = status_key_name.replace('JobStatus', ' job')
# --> 928             raise ValueError('Error for {} {}: {} Reason: {}'.format(job_type, job, status, reason))
#     929
#     930     def wait_for_endpoint(self, endpoint, poll=5):
#
# ValueError: Error for Transform job xgboost-190629-2331-018-cfe1d7a8-2019-06-30-00-41-01-209: Failed Reason: ClientError: See job logs for more information

# %% [markdown]
# Now the transform job has executed and the result, the estimated sentiment of each review, has been saved on S3. Since we would rather work on this file locally we can perform a bit of notebook magic to copy the file to the `data_dir`.

# %%
# !aws s3 cp --recursive $xgb_transformer.output_path $data_dir

# %% [markdown]
# The last step is now to read in the output from our model, convert the output to something a little more usable, in this case we want the sentiment to be either `1` (positive) or `0` (negative), and then compare to the ground truth labels.

# %%
predictions = pd.read_csv(os.path.join(data_dir, 'test.csv.out'), header=None)
predictions = [round(num) for num in predictions.squeeze().values]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-31-123e18e60ff0> in <module>()
# ----> 1 predictions = pd.read_csv(os.path.join(data_dir, 'test.csv.out'), header=None)
#       2 predictions = [round(num) for num in predictions.squeeze().values]
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'../data/xgboost/test.csv.out' does not exist: b'../data/xgboost/test.csv.out'

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_y, predictions)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-43c245f597b9> in <module>()
#       1 from sklearn.metrics import accuracy_score
# ----> 2 accuracy_score(test_y, predictions)
#
# NameError: name 'predictions' is not defined

# %% [markdown]
# ## Optional: Clean up
#
# The default notebook instance on SageMaker doesn't have a lot of excess disk space available. As you continue to complete and execute notebooks you will eventually fill up this disk space, leading to errors which can be difficult to diagnose. Once you are completely finished using a notebook it is a good idea to remove the files that you created along the way. Of course, you can do this from the terminal or from the notebook hub if you would like. The cell below contains some commands to clean up the created files from within the notebook.

# %%
# First we will remove all of the files contained in the data_dir directory
# !rm $data_dir/*

# And then we delete the directory itself
# !rmdir $data_dir

# Similarly we will remove the files in the cache_dir directory and the directory itself
# !rm $cache_dir/*
# !rmdir $cache_dir
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-14-5047072eb3f9> in <module>()
#       1 # First we will remove all of the files contained in the data_dir directory
# ----> 2 get_ipython().system('rm $data_dir/*')
#       3
#       4 # And then we delete the directory itself
#       5 get_ipython().system('rmdir $data_dir')
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/IPython/core/interactiveshell.py in system_piped(self, cmd)
#    2259         # a non-None value would trigger :func:`sys.displayhook` calls.
#    2260         # Instead, we store the exit_code in user_ns.
# -> 2261         self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#    2262
#    2263     def system_raw(self, cmd):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     154                 child = pexpect.spawnb(self.sh, args=['-c', cmd]) # Pexpect-U
#     155             else:
# --> 156                 child = pexpect.spawn(self.sh, args=['-c', cmd])  # Vanilla Pexpect
#     157             flush = sys.stdout.flush
#     158             while True:
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pexpect/pty_spawn.py in __init__(self, command, args, timeout, maxread, searchwindowsize, logfile, cwd, env, ignore_sighup, echo, preexec_fn, encoding, codec_errors, dimensions, use_poll)
#     202             self.name = '<pexpect factory incomplete>'
#     203         else:
# --> 204             self._spawn(command, args, preexec_fn, dimensions)
#     205         self.use_poll = use_poll
#     206
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pexpect/pty_spawn.py in _spawn(self, command, args, preexec_fn, dimensions)
#     301
#     302         self.ptyproc = self._spawnpty(self.args, env=self.env,
# --> 303                                      cwd=self.cwd, **kwargs)
#     304
#     305         self.pid = self.ptyproc.pid
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pexpect/pty_spawn.py in _spawnpty(self, args, **kwargs)
#     312     def _spawnpty(self, args, **kwargs):
#     313         '''Spawn a pty and return an instance of PtyProcess.'''
# --> 314         return ptyprocess.PtyProcess.spawn(args, **kwargs)
#     315
#     316     def close(self, force=True):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/ptyprocess/ptyprocess.py in spawn(cls, argv, cwd, env, echo, preexec_fn, dimensions)
#     220
#     221         if use_native_pty_fork:
# --> 222             pid, fd = pty.fork()
#     223         else:
#     224             # Use internal fork_pty, for Solaris
#
# ~/anaconda3/envs/python3/lib/python3.6/pty.py in fork()
#      95
#      96     master_fd, slave_fd = openpty()
# ---> 97     pid = os.fork()
#      98     if pid == CHILD:
#      99         # Establish a new session.
#
# OSError: [Errno 12] Cannot allocate memory

# %%
cd /tmp
rm -r
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-c7c97a5e6e45> in <module>()
# ----> 1 cd /tmp
#       2 rm -r
#
# NameError: name 'cd' is not defined
